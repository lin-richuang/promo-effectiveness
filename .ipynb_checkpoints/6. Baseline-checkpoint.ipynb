# %% [markdown]
# # Baseline of non promo sales

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import pickle
import warnings
import matplotlib.pyplot as plt

warnings.simplefilter("ignore")
pd.options.display.max_columns = None

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Read data

# %%
saved_embeddings_fname = "models/embeddings.pickle" 
label_encoder_pickle = 'models/les.pickle'
embedded_ridge_model = 'models/embedded_ridge_model.pickle'

# %%
processed_path = 'processed/'
processed_file = 'processed_data.csv'
df = pd.read_csv(processed_path + processed_file)

# %% [markdown]
# # Baseline set promo = 0

# %%
df['Promo_original'] = df['Promo']
df['Promo'] = 0

# %%
df
# Out:
#         Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0        1097          2  2013-01-01   5961       1405     1      0
# 1          85          2  2013-01-01   4220        619     1      0
# 2         259          2  2013-01-01   6851       1444     1      0
# 3         262          2  2013-01-01  17267       2875     1      0
# 4         274          2  2013-01-01   3102        729     1      0
# ...       ...        ...         ...    ...        ...   ...    ...
# 844333    745          5  2015-07-31   8363        746     1      0
# 844334    746          5  2015-07-31   9082        638     1      0
# 844335    747          5  2015-07-31  10708        826     1      0
# 844336    741          5  2015-07-31  11253       1137     1      0
# 844337      1          5  2015-07-31   5263        555     1      0
#
#         SchoolHoliday  year  weekofyear  Promo_original  holiday
# 0                   1  2013           1               0        1
# ...

# %% [markdown]
# # Preprocessing

# %%
def consolidate_holiday(df):
    df['holiday'] = 0
    df.loc[df['holiday_public'] ==1, 'holiday'] = 1
    df.loc[df['holiday_easter'] ==1, 'holiday'] = 2
    df.loc[df['holiday_christmas'] ==1, 'holiday'] = 3
    return df.drop(columns = ['holiday_public', 'holiday_no', 'holiday_easter', 'holiday_christmas'])

# %%
df = consolidate_holiday(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/embedding/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'holiday_public'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-ff42a27951a1> in <module>
# ...

# %%
X = df[['Store', 'year','weekofyear','DayOfWeek',  'holiday', 
        'Promo', 'SchoolHoliday']]
X_np = X.to_numpy()

# %%
# Load LabelEncoders
with open(label_encoder_pickle, 'rb') as f:
    les = pickle.load(f)

# %%
for i in range(5):
    """ Only need to encode the first 5 columns
    """
    X_np[:, i] = les[i].transform(X_np[:, i])

# %%
def embed_features(X, saved_embeddings_fname):
    # f_embeddings = open("embeddings_shuffled.pickle", "rb")
    f_embeddings = open(saved_embeddings_fname, "rb")
    embeddings = pickle.load(f_embeddings)

    # first number is the column number of the data
    # second number is the number of embedding file
    index_embedding_mapping = {0: 0, 1: 1, 2: 2, 3: 3, 4: 4}
    X_embedded = []

    for record in X:
        embedded_features = []
        for i, feat in enumerate(record):
            feat = int(feat)
            if i not in index_embedding_mapping.keys():
                embedded_features += [feat]
            else:
                embedding_index = index_embedding_mapping[i]
                embedded_features += embeddings[embedding_index][feat].tolist()

        X_embedded.append(embedded_features)

    return np.array(X_embedded)

# %%
pred_embedded = embed_features(X_np, saved_embeddings_fname)

# %% [markdown]
# # Prediction

# %%
# Load model
with open(embedded_ridge_model, 'rb') as f:
    ridge_model = pickle.load(f)

# %%
df['prediction']= np.exp(ridge_model.predict(pred_embedded)).astype(int)

# %% [markdown]
# # Evaluation

# %%
def mape(y_true, y_pred):
    """Mean absolute percent error
    How far away prediction from true value
    """
    relative_err = np.absolute((y_pred - y_true) / y_true)
    result = np.sum(relative_err) / len(y_true)
    return result

def mpe(y_true, y_pred):
    """Evaluate result if prediction is consistently higher or lower
    Ideally to see 0 since all higher and lower would zero out. 
    """
    relative_err = ((y_pred - y_true) / y_true)
    result = np.sum(relative_err) / len(y_true)
    return result

# %%
mape(df.Sales, df.prediction)
# Out:
# 0.2156237471753564

# %%
mpe(df.Sales, df.prediction)
# Out:
# -0.10610306365202046

# %% [markdown]
# Seems to be consistently under predicting

# %% [markdown]
# ## Let`s see how good the baseline is

# %%
non_promo_df = df.loc[df['Promo_original']==0]

# %%
mape(non_promo_df.Sales, non_promo_df.prediction)
# Out:
# 0.16839214573985434

# %%
mpe(non_promo_df.Sales, non_promo_df.prediction)
# Out:
# 0.0246170991385419

# %% [markdown]
# Pretty good baseline

# %% [markdown]
# # Plot one store

# %%
df['Date'] = pd.to_datetime(df['Date'], infer_datetime_format=True)
test_store = df.loc[df['Store']==817]

# %%
test_store_bl = test_store.loc[test_store['Promo_original']==0]

# %%
plt.figure(figsize = (16,8))
plt.plot(test_store['Date'], test_store['Sales'], 'r', label ='Actual')
plt.plot(test_store['Date'], test_store['prediction'], 'b--', label = 'prediction')
plt.legend()

# %%
plt.figure(figsize = (16,8))
plt.plot(test_store_bl['Date'], test_store_bl['Sales'], label = 'non-promo sales')
plt.plot(test_store_bl['Date'], test_store_bl['prediction'], 'b--', label = 'baseline')
plt.legend()

# %% [markdown]
# Not bad for a model only learning from very few features.
