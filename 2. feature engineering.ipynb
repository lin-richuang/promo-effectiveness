# %%
"""
Feature engineering 

As from last notebook, we need to do following in feature engineering
- exclude 0 sales
- exclude store closure
- state holiday: one hot encoding
- date: add year, month, week, quarter, delete date
"""
# Out:
# '\nFeature engineering \n\nAs from last notebook, we need to do following in feature engineering\n- exclude 0 sales\n- exclude store closure\n- state holiday: one hot encoding\n- date: add year, month, week, quarter, delete date\n'

# %%
import pandas as pd
import warnings
import seaborn as sns

warnings.simplefilter("ignore")
pd.options.display.max_columns = None

# %%
input_path = 'rossmann/'
input_file = 'train.csv'
processed_path = 'processed/'
processed_file = 'processed_data.csv'

# %%
df_train = pd.read_csv(input_path + input_file)

# %% [markdown]
# # Exclude 0 sales and store closure

# %%
def exclude_store_closure_and_zero(df):
    df = df.loc[df['Sales']>0]
    return df.loc[df['Open']==1].reset_index(drop=True)

# %%
df = exclude_store_closure_and_zero(df_train)

# %%
df.shape
# Out:
# (844338, 9)

# %%
df
# Out:
#         Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0           1          5  2015-07-31   5263        555     1      1
# 1           2          5  2015-07-31   6064        625     1      1
# 2           3          5  2015-07-31   8314        821     1      1
# 3           4          5  2015-07-31  13995       1498     1      1
# 4           5          5  2015-07-31   4822        559     1      1
# ...       ...        ...         ...    ...        ...   ...    ...
# 844333    682          2  2013-01-01   3375        566     1      0
# 844334    733          2  2013-01-01  10765       2377     1      0
# 844335    769          2  2013-01-01   5035       1248     1      0
# 844336    948          2  2013-01-01   4491       1039     1      0
# 844337   1097          2  2013-01-01   5961       1405     1      0
#
#        StateHoliday  SchoolHoliday
# 0                 0              1
# 1                 0              1
# 2                 0              1
# 3                 0              1
# 4                 0              1
# ...             ...            ...
# 844333            a              1
# 844334            a              1
# 844335            a              1
# 844336            a              1
# 844337            a              1
#
# [844338 rows x 9 columns]

# %% [markdown]
# # Deal with state holiday

# %%
def one_hot_encoding_state_holiday(df):
    """a = public holiday, b = Easter holiday, c = Christmas, 0 = None
    """
    df.loc[df['StateHoliday'] == 0, 'StateHoliday'] = '0'
    state_dummy = df.pop('StateHoliday')
    state_dummy = pd.get_dummies(state_dummy)
    state_dummy.rename(columns={'0': 'holiday_no', 'a': 'holiday_public', 
                               'b': 'holiday_easter', 'c':'holiday_christmas'}, inplace=True)
    
    combined = pd.concat([df, state_dummy], axis =1)
    return combined

# %%
df = one_hot_encoding_state_holiday(df)

# %% [markdown]
# # Date

# %%
def add_year_month(df):
    df['Date'] = pd.to_datetime(df['Date'], infer_datetime_format=True)
    df = df.sort_values('Date', ascending = True)
    df['year'] = df['Date'].dt.year
#     df['month'] = df['Date'].dt.month
#     df['quarter'] = df['Date'].dt.quarter
    df['weekofyear'] = df['Date'].dt.weekofyear
    return df.drop(columns ='Date')

# %%
df = add_year_month(df)

# %%
df
# Out:
#         Store  DayOfWeek  Sales  Customers  Open  Promo  SchoolHoliday  \
# 0           1          5   5263        555     1      1              1
# 1           2          5   6064        625     1      1              1
# 2           3          5   8314        821     1      1              1
# 3           4          5  13995       1498     1      1              1
# 4           5          5   4822        559     1      1              1
# ...       ...        ...    ...        ...   ...    ...            ...
# 844333    682          2   3375        566     1      0              1
# 844334    733          2  10765       2377     1      0              1
# 844335    769          2   5035       1248     1      0              1
# 844336    948          2   4491       1039     1      0              1
# 844337   1097          2   5961       1405     1      0              1
#
#         holiday_no  holiday_public  holiday_easter  holiday_christmas  year  \
# 0                1               0               0                  0  2015
# 1                1               0               0                  0  2015
# 2                1               0               0                  0  2015
# 3                1               0               0                  0  2015
# 4                1               0               0                  0  2015
# ...            ...             ...             ...                ...   ...
# 844333           0               1               0                  0  2013
# 844334           0               1               0                  0  2013
# 844335           0               1               0                  0  2013
# 844336           0               1               0                  0  2013
# 844337           0               1               0                  0  2013
#
#         month
# 0           7
# 1           7
# 2           7
# 3           7
# 4           7
# ...       ...
# 844333      1
# 844334      1
# 844335      1
# 844336      1
# 844337      1
#
# [844338 rows x 13 columns]

# %% [markdown]
# # Remove columns not going to be used

# %%
def remove_useless_columns(df):
    cols = ['Customers','Open']
    return df.drop(columns = cols)

# %%
df = remove_useless_columns(df)

# %%
df
# Out:
#         Store  DayOfWeek  Sales  Promo  SchoolHoliday  holiday_no  \
# 0           1          5   5263      1              1           1
# 1           2          5   6064      1              1           1
# 2           3          5   8314      1              1           1
# 3           4          5  13995      1              1           1
# 4           5          5   4822      1              1           1
# ...       ...        ...    ...    ...            ...         ...
# 844333    682          2   3375      0              1           0
# 844334    733          2  10765      0              1           0
# 844335    769          2   5035      0              1           0
# 844336    948          2   4491      0              1           0
# 844337   1097          2   5961      0              1           0
#
#         holiday_public  holiday_easter  holiday_christmas  year  month
# 0                    0               0                  0  2015      7
# 1                    0               0                  0  2015      7
# 2                    0               0                  0  2015      7
# 3                    0               0                  0  2015      7
# 4                    0               0                  0  2015      7
# ...                ...             ...                ...   ...    ...
# 844333               1               0                  0  2013      1
# 844334               1               0                  0  2013      1
# 844335               1               0                  0  2013      1
# 844336               1               0                  0  2013      1
# 844337               1               0                  0  2013      1
#
# [844338 rows x 11 columns]

# %% [markdown]
# # Combine all together

# %%
def feature_engineering(df):
    df = exclude_store_closure_and_zero(df)
    df = one_hot_encoding_state_holiday(df)
    df = add_year_month(df)
    df = remove_useless_columns(df)
    return df

# %%
df = feature_engineering(df_train)

# %%
df
# Out:
#         Store  DayOfWeek  Sales  Promo  SchoolHoliday  holiday_no  \
# 844337   1097          2   5961      0              1           0
# 844321     85          2   4220      0              1           0
# 844322    259          2   6851      0              1           0
# 844323    262          2  17267      0              1           0
# 844324    274          2   3102      0              1           0
# ...       ...        ...    ...    ...            ...         ...
# 743       745          5   8363      1              1           1
# 744       746          5   9082      1              1           1
# 745       747          5  10708      1              1           1
# 739       741          5  11253      1              1           1
# 0           1          5   5263      1              1           1
#
#         holiday_public  holiday_easter  holiday_christmas  year  weekofyear
# 844337               1               0                  0  2013           1
# 844321               1               0                  0  2013           1
# 844322               1               0                  0  2013           1
# 844323               1               0                  0  2013           1
# 844324               1               0                  0  2013           1
# ...                ...             ...                ...   ...         ...
# 743                  0               0                  0  2015          31
# 744                  0               0                  0  2015          31
# 745                  0               0                  0  2015          31
# 739                  0               0                  0  2015          31
# 0                    0               0                  0  2015          31
#
# [844338 rows x 11 columns]

# %% [markdown]
# # Save to processed folder

# %%
df.to_csv(processed_path + processed_file, index=False)
